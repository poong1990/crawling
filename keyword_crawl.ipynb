# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
import pandas as pd 
from selenium.webdriver.common.action_chains import ActionChains
import re

# %%
# 유튜브 기본 url - 채널 href 없는 경우, 영상 다이렉트링크에 붙여넣을 때 사용
base_url = 'https://www.youtube.com'

# 검색창에 # 붙인 상태
url = 'https://www.youtube.com/results?search_query=%23'

# 검색 필터(동영상만 보이기, 관련성 기준) 추가 url
last_url = '&sp=EgIQAQ%253D%253D'

# 검색어
keyword = input()

# '# 검색어' 최종 url
search = url+keyword+last_url

# 데이터 들어갈 빈 리스트
urls = []
titles = []
thumbnails = []
host_urls = []
youtube_url = []
youtube_thumbnail = []
youtube_title = []
youtube_host_url = []
youtube_avatar = []
collect = []

df_url = []
df_title = []
df_host = []
df_host_url = []
df_avatar = []
df_follow = []
df_upload = []
df_view = []
df_thumbnail = []
df_likes = []
df_hates = []
df_comment = []

# 크롬드라이버로 단어 검색하기
driver = webdriver.Chrome('chromedriver.exe')
driver.get(search)
driver.implicitly_wait(5.0)

# 영상 목록 스크롤 10번한 뒤 영상들의 제목 따오기
for i in range(10) :
    ActionChains(driver).send_keys(Keys.END).perform()
    time.sleep(0.5)
    html_source = driver.page_source
    soup = BeautifulSoup(html_source, 'lxml')
    videos = soup.select('h3 > #video-title')

# 영상 url, 제목, 썸네일, 유튜버채널url 가져오기
# 썸네일, 채널url이 비어있는 경우에는 가상이미지, 유튜브기본url로 대체
for i in range(len(videos)): 
    urls.append(base_url + soup.select('h3 > #video-title')[i]['href'])
    titles.append(soup.select('h3 > #video-title')[i]['title'])
    try:
        thumbnail = soup.select('#dismissable > ytd-thumbnail > #thumbnail > yt-img-shadow > #img')[i]['src']
        thumbnail = thumbnail.replace('&', '&amp;')
        thumbnails.append(thumbnail)
    except:
        thumbnail = 'https://via.placeholder.com/1280x720'
        thumbnails.append(thumbnail)
    try:
        host_url = soup.select('#container > #text-container > #text > a')[i]['href']
        host_urls.append(base_url + host_url)
    except:
        host_urls.append(base_url)
        
driver.close()

# 영상제목이 영어+특수문자인 경우만 필터링
for i in range(len(titles)) :
    if re.match('[!-~·\s]+', titles[i]) == None :
        collect.append(None)
    else :
        if re.match('[!-~\s]+', titles[i]).group() == titles[i] :
            collect.append(titles[i])
        else :
            collect.append(None)

# 영어제목의 영상url, 썸네일, 채널url, 제목만 저장  
for i in range(len(collect)) :
    if collect[i] != None :
        youtube_url.append(urls[i])
        youtube_thumbnail.append(thumbnails[i])
        youtube_host_url.append(host_urls[i])
        youtube_title.append(titles[i])
        
print(youtube_url)

# 필터링 된 상태의 url로 반복문
for i in range(len(youtube_url)) :
    
    driver = webdriver.Chrome('chromedriver.exe')
    driver.get(youtube_url[i])
    driver.implicitly_wait(5.0)
    time.sleep(3.0)

    # 영어설정 되면 설정하고 안되면 해당영상 건너뛰기
    try :
        driver.find_elements_by_xpath('//*[@id="buttons"]/ytd-topbar-menu-button-renderer[3]')[0].click()
        driver.find_elements_by_xpath('//*[@id="endpoint"]/paper-item')[0].click()
        driver.find_elements_by_xpath('//*[@id="settings"]/ytd-account-settings/div/div[2]/paper-item[13]')[0].click()
    except :
        driver.close()
        continue
    
    time.sleep(3.0)
    
    # 행 갯수를 맞춰서 복붙하기 위해 미리 영상별로 변수에 삽입
    this_url = youtube_url[i]
    this_thumbnail = youtube_thumbnail[i]
    this_host_url = youtube_host_url[i]
    this_title = youtube_title[i]
    
    # 자동스크롤 100번 하기
    # 그냥 END 키만 누르면 영상끝으로 가는 경우도 있어 ctrl + end 키로 작업
    for i in range(100) : 
        ActionChains(driver).send_keys(Keys.CONTROL).send_keys(Keys.END).perform()
        time.sleep(0.5)
    
    # 스크롤 완료되면 유튜버이름, 아바타이미지, 구독자수, 영상업로드날짜, 영상별조회수, 댓글 가져오기
    html_source = driver.page_source
    soup = BeautifulSoup(html_source, 'lxml')
        
    host = soup.select('#text > a')
    try:
        avatar = soup.select('#avatar > #img')[0]['src']
    except:
        avatar = 'https://via.placeholder.com/48x48'
    follow = soup.select('#owner-sub-count')
    upload = soup.select('#date > yt-formatted-string')
    view = soup.select('#count > yt-view-count-renderer > span.view-count.style-scope.yt-view-count-renderer')
    likeshates = soup.select('#top-level-buttons > ytd-toggle-button-renderer > a > #text')
    comment = soup.select('#content-text')

    # 각 영상별로 댓글수만큼 나머지 컬럼 복붙
    for i in range(len(comment)):

        # url
        df_url.append(this_url)

        # title
        df_title.append(this_title)

        # 호스트 url
        df_host_url.append(this_host_url)
        
        # 사진
        df_avatar.append(avatar)
                
        # 썸네일
        df_thumbnail.append(this_thumbnail)
        
        # 호스트
        str_host = host[0].text
        df_host.append(str_host)
        
        # 구독자
        str_follow = follow[0].text
        df_follow.append(str_follow)

        # 영상 작성일자
        str_upload = upload[0].text
        df_upload.append(str_upload)

        # 재생횟수
        str_view = view[0].text
        df_view.append(str_view)
        
        # 좋아요
        str_likes = likeshates[0].text
        df_likes.append(str_likes)
        # 싫어요
        str_hates = likeshates[1].text
        df_hates.append(str_hates)
        
        # 내용
        str_comment = str(comment[i].text)
        str_comment = str_comment.replace('\n', '')
        str_comment = str_comment.replace('\t','')
        str_comment = str_comment.replace('               ', '')
#         df_comment.append(str_comment)
        
        # 댓글내용 영어만 골라서 다시 저장하기
        m = re.findall("[a-zA-Z']+", str_comment)
        a = ''
        for i in m :
            a = a + ' ' + i
        df_comment.append(a)
        
    print(this_url)
    driver.close()

# 데이터프레임 만들고 '검색어.csv' 로 저장 
youtube_df = pd.DataFrame({
    "url" : df_url,
    "title" : df_title,
    "host" : df_host,
    "host_url" : df_host_url,
    "avatar" : df_avatar,
    "follow" : df_follow,
    "upload" : df_upload,
    "view" : df_view,
    "thumbnail" : df_thumbnail,
    "likes" : df_likes,
    "hates" : df_hates,
    "comment" : df_comment
})

# SQL에 넣기위해 콤마 제거, 댓글내용중에 영어만 저장
youtube_df['title'] = youtube_df['title'].str.replace(',', ' ')
youtube_df['view'] = youtube_df['view'].str.replace(',', '')
youtube_df['comment'] = youtube_df['comment'].str.replace(',', ' ')
youtube_df.dropna(inplace = True)
print(youtube_df)
youtube_df.to_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/{}.csv'.format(keyword), 
                  encoding = 'utf-8', index = False)
# Out:
# ufc
# ['https://www.youtube.com/watch?v=X1TvrRq5HgM', 'https://www.youtube.com/watch?v=nfuDx9cNgno', 'https://www.youtube.com/watch?v=YGwAaRllFm0', 'https://www.youtube.com/watch?v=IehS6cW6RDY', 'https://www.youtube.com/watch?v=L0GH5cw4ajo', 'https://www.youtube.com/watch?v=okEA5d1Ebe4', 'https://www.youtube.com/watch?v=ATCPp6D9sjM', 'https://www.youtube.com/watch?v=5ayQ16HGjIM', 'https://www.youtube.com/watch?v=iH_VKkVZigk', 'https://www.youtube.com/watch?v=RtkHZfcDtpY', 'https://www.youtube.com/watch?v=51DBalG3Bww', 'https://www.youtube.com/watch?v=XwbQaEiAaLw', 'https://www.youtube.com/watch?v=3AW7ekfiiVo', 'https://www.youtube.com/watch?v=fkmIrwKT2q8', 'https://www.youtube.com/watch?v=AdLLoxHEpZg', 'https://www.youtube.com/watch?v=HelivOF6vI8', 'https://www.youtube.com/watch?v=WRfJYdDzpOw', 'https://www.youtube.com/watch?v=MljHo7hLhGw', 'https://www.youtube.com/watch?v=HTB1s4goPUg', 'https://www.youtube.com/watch?v=BV3FcAecXL0', 'https://www.youtube.com/watch?v=J_0ZOWobg3U', 'https://www.youtube.com/watch?v=U90zzwiKQX8', 'https://www.youtube.com/watch?v=w2i_8yFmfgE', 'https://www.youtube.com/watch?v=lNseUnqPLc8', 'https://www.youtube.com/watch?v=e1MTs3n0yJ4', 'https://www.youtube.com/watch?v=05HuTGeF5AA', 'https://www.youtube.com/watch?v=5cAL1K6Dklg', 'https://www.youtube.com/watch?v=N5kAB-FtxkY', 'https://www.youtube.com/watch?v=XqN0OzP32mA', 'https://www.youtube.com/watch?v=-6RY80mgNro', 'https://www.youtube.com/watch?v=nYuKD4CsqYM', 'https://www.youtube.com/watch?v=KgoQ4h97Sxc', 'https://www.youtube.com/watch?v=1OphXMJin6I', 'https://www.youtube.com/watch?v=0huqrQR_3HA', 'https://www.youtube.com/watch?v=Yvaog5dTBKw', 'https://www.youtube.com/watch?v=vyOcXwmmPEw', 'https://www.youtube.com/watch?v=IarVtlYpxtE', 'https://www.youtube.com/watch?v=nMRyIaA66HI', 'https://www.youtube.com/watch?v=FiCcFdg6ICI', 'https://www.youtube.com/watch?v=_bGeqY6LekQ', 'https://www.youtube.com/watch?v=1AuCXK70sIQ', 'https://www.youtube.com/watch?v=djU-3l_CIWU', 'https://www.youtube.com/watch?v=yoUbQxvDVss', 'https://www.youtube.com/watch?v=moNsL5OYbC4', 'https://www.youtube.com/watch?v=rrHnH7xwjZk', 'https://www.youtube.com/watch?v=-WDQlw4IAGg', 'https://www.youtube.com/watch?v=ULKXidThmdY', 'https://www.youtube.com/watch?v=igLNSW8tW8s', 'https://www.youtube.com/watch?v=vu1QpsQOMow', 'https://www.youtube.com/watch?v=lX1ZorM3DGY', 'https://www.youtube.com/watch?v=Q291I35H174', 'https://www.youtube.com/watch?v=zwa49OAlOFs', 'https://www.youtube.com/watch?v=T_jyPnHyytQ', 'https://www.youtube.com/watch?v=b_UQ2qgu3tw', 'https://www.youtube.com/watch?v=AETfB4wB4fk', 'https://www.youtube.com/watch?v=wKWFb6nHJws', 'https://www.youtube.com/watch?v=pqTxkkVsOoU', 'https://www.youtube.com/watch?v=dbOwc9wbPWQ', 'https://www.youtube.com/watch?v=P2knU603qBw', 'https://www.youtube.com/watch?v=8w2OhgDe4rY', 'https://www.youtube.com/watch?v=Fva1nfvk8JM', 'https://www.youtube.com/watch?v=tnulVfHQz60', 'https://www.youtube.com/watch?v=RRbKs2NoYkA', 'https://www.youtube.com/watch?v=ptxAslIwvYI', 'https://www.youtube.com/watch?v=5TnawSliTUg', 'https://www.youtube.com/watch?v=-vBUal9-Yzc', 'https://www.youtube.com/watch?v=CG0HUb4aisA', 'https://www.youtube.com/watch?v=bRmHCayZRhA', 'https://www.youtube.com/watch?v=ojMpIPKElSw', 'https://www.youtube.com/watch?v=H8ro-DmgLxs', 'https://www.youtube.com/watch?v=To9dKnnPIWc', 'https://www.youtube.com/watch?v=-CMLTFP0BFo', 'https://www.youtube.com/watch?v=eNnoXPfSOBA', 'https://www.youtube.com/watch?v=8Bz0Qn85sWk', 'https://www.youtube.com/watch?v=ESM13QCTjxY', 'https://www.youtube.com/watch?v=GKMXUXWh_Oc', 'https://www.youtube.com/watch?v=EXpOQROXSpo', 'https://www.youtube.com/watch?v=BOOlIXLOQ40', 'https://www.youtube.com/watch?v=MJdkTB1xNVA', 'https://www.youtube.com/watch?v=-p0mzE3sXzA', 'https://www.youtube.com/watch?v=0FsBvCewCco', 'https://www.youtube.com/watch?v=3ZtBKpjgA1Y', 'https://www.youtube.com/watch?v=qfvFm1cJzL4', 'https://www.youtube.com/watch?v=1U0_xB4vbDk', 'https://www.youtube.com/watch?v=j--jiMkSPqw', 'htt ...
# https://www.youtube.com/watch?v=X1TvrRq5HgM
# https://www.youtube.com/watch?v=nfuDx9cNgno
# https://www.youtube.com/watch?v=YGwAaRllFm0
# https://www.youtube.com/watch?v=IehS6cW6RDY
# https://www.youtube.com/watch?v=L0GH5cw4ajo
# https://www.youtube.com/watch?v=okEA5d1Ebe4
# https://www.youtube.com/watch?v=ATCPp6D9sjM
# https://www.youtube.com/watch?v=5ayQ16HGjIM
# https://www.youtube.com/watch?v=iH_VKkVZigk
# https://www.youtube.com/watch?v=RtkHZfcDtpY
# https://www.youtube.com/watch?v=51DBalG3Bww
# https://www.youtube.com/watch?v=XwbQaEiAaLw
# https://www.youtube.com/watch?v=3AW7ekfiiVo
# https://www.youtube.com/watch?v=fkmIrwKT2q8
# https://www.youtube.com/watch?v=AdLLoxHEpZg
# https://www.youtube.com/watch?v=HelivOF6vI8
# https://www.youtube.com/watch?v=WRfJYdDzpOw
# https://www.youtube.com/watch?v=MljHo7hLhGw
# https://www.youtube.com/watch?v=HTB1s4goPUg
# https://www.youtube.com/watch?v=BV3FcAecXL0
# https://www.youtube.com/watch?v=J_0ZOWobg3U
# https://www.youtube.com/watch?v=U90zzwiKQX8
# https://www.youtube.com/watch?v=w2i_8yFmfgE
# https://www.youtube.com/watch?v=lNseUnqPLc8
# https://www.youtube.com/watch?v=e1MTs3n0yJ4
# https://www.youtube.com/watch?v=05HuTGeF5AA
# https://www.youtube.com/watch?v=5cAL1K6Dklg
# https://www.youtube.com/watch?v=N5kAB-FtxkY
# https://www.youtube.com/watch?v=XqN0OzP32mA
# https://www.youtube.com/watch?v=-6RY80mgNro
# https://www.youtube.com/watch?v=nYuKD4CsqYM
# https://www.youtube.com/watch?v=KgoQ4h97Sxc
# https://www.youtube.com/watch?v=1OphXMJin6I
# https://www.youtube.com/watch?v=0huqrQR_3HA
# https://www.youtube.com/watch?v=Yvaog5dTBKw
# https://www.youtube.com/watch?v=vyOcXwmmPEw
# https://www.youtube.com/watch?v=IarVtlYpxtE
# https://www.youtube.com/watch?v=nMRyIaA66HI
# https://www.youtube.com/watch?v=FiCcFdg6ICI
# https://www.youtube.com/watch?v=_bGeqY6LekQ
# https://www.youtube.com/watch?v=1AuCXK70sIQ
# https://www.youtube.com/watch?v=djU-3l_CIWU
# https://www.youtube.com/watch?v=yoUbQxvDVss
# https://www.youtube.com/watch?v=moNsL5OYbC4
# https://www.youtube.com/watch?v=rrHnH7xwjZk
# https://www.youtube.com/watch?v=-WDQlw4IAGg
# https://www.youtube.com/watch?v=ULKXidThmdY
# https://www.youtube.com/watch?v=igLNSW8tW8s
# https://www.youtube.com/watch?v=vu1QpsQOMow
# https://www.youtube.com/watch?v=lX1ZorM3DGY
# https://www.youtube.com/watch?v=Q291I35H174
# https://www.youtube.com/watch?v=zwa49OAlOFs
# https://www.youtube.com/watch?v=T_jyPnHyytQ
# https://www.youtube.com/watch?v=b_UQ2qgu3tw
# https://www.youtube.com/watch?v=AETfB4wB4fk
# https://www.youtube.com/watch?v=wKWFb6nHJws
# https://www.youtube.com/watch?v=pqTxkkVsOoU
# https://www.youtube.com/watch?v=dbOwc9wbPWQ
# https://www.youtube.com/watch?v=P2knU603qBw
# https://www.youtube.com/watch?v=8w2OhgDe4rY
# https://www.youtube.com/watch?v=Fva1nfvk8JM
# https://www.youtube.com/watch?v=tnulVfHQz60
# https://www.youtube.com/watch?v=RRbKs2NoYkA
# https://www.youtube.com/watch?v=ptxAslIwvYI
# https://www.youtube.com/watch?v=5TnawSliTUg
# https://www.youtube.com/watch?v=-vBUal9-Yzc
# https://www.youtube.com/watch?v=CG0HUb4aisA
# https://www.youtube.com/watch?v=bRmHCayZRhA
# https://www.youtube.com/watch?v=ojMpIPKElSw
# https://www.youtube.com/watch?v=H8ro-DmgLxs
# https://www.youtube.com/watch?v=To9dKnnPIWc
# https://www.youtube.com/watch?v=-CMLTFP0BFo
# https://www.youtube.com/watch?v=eNnoXPfSOBA
# https://www.youtube.com/watch?v=8Bz0Qn85sWk
# https://www.youtube.com/watch?v=ESM13QCTjxY
# https://www.youtube.com/watch?v=GKMXUXWh_Oc
# https://www.youtube.com/watch?v=EXpOQROXSpo
# https://www.youtube.com/watch?v=BOOlIXLOQ40
# https://www.youtube.com/watch?v=MJdkTB1xNVA
# https://www.youtube.com/watch?v=-p0mzE3sXzA
# https://www.youtube.com/watch?v=0FsBvCewCco
# https://www.youtube.com/watch?v=3ZtBKpjgA1Y
# https://www.youtube.com/watch?v=qfvFm1cJzL4
# https://www.youtube.com/watch?v=1U0_xB4vbDk
# https://www.youtube.com/watch?v=j--jiMkSPqw
# https://www.youtube.com/watch?v=YeVnGGKsxEw
# https://www.youtube.com/watch?v=4i2WidHcBxQ
# https://www.youtube.com/watch?v=TJ94xgqPKSw
# https://www.youtube.com/watch?v=SG_ooc4GaeQ
# https://www.youtube.com/watch?v=ftjDHc042xU
# https://www.youtube.com/watch?v=OTNO3823Pow
# https://www.youtube.com/watch?v=-g88odXOrHA
# https://www.youtube.com/watch?v=78qRb-e2et4
# https://www.youtube.com/watch?v=_FakdYGQ1io
# https://www.youtube.com/watch?v=ITkL6NY3VJM
# https://www.youtube.com/watch?v=ZIrQZeHcwI4
# https://www.youtube.com/watch?v=uAgtrZoApSg
# https://www.youtube.com/watch?v=5khE_hgWY_o
# https://www.youtube.com/watch?v=yAqnRCQ9Abc
# https://www.youtube.com/watch?v=yqKj9tjsZ8g
# https://www.youtube.com/watch?v=Yz1P0OcLVhc
# https://www.youtube.com/watch?v=p7t8ogT28yY
# https://www.youtube.com/watch?v=4kxLg16Zyt0
# https://www.youtube.com/watch?v=mINcFNbscQw
# https://www.youtube.com/watch?v=l-Er0ttf52Y
# https://www.youtube.com/watch?v=YxNAoHY405E
# https://www.youtube.com/watch?v=2exsQ-1Cuh0
# https://www.youtube.com/watch?v=EcucjWSDlqU
# https://www.youtube.com/watch?v=mxnCFQq247c
# https://www.youtube.com/watch?v=gISdoBJDqTo
# https://www.youtube.com/watch?v=po4uSmlCJlc
# https://www.youtube.com/watch?v=HMrjxhaq8Tg
# https://www.youtube.com/watch?v=pZwPILaudgY
# https://www.youtube.com/watch?v=11FKpmNCIGM
# https://www.youtube.com/watch?v=Pb6zajmjjlw
# https://www.youtube.com/watch?v=jWCcaWSkw20
# https://www.youtube.com/watch?v=Q3LfjlnAXMw
# https://www.youtube.com/watch?v=pM86pzum1Ik
# https://www.youtube.com/watch?v=5yUGYysgFjE
# https://www.youtube.com/watch?v=K702FXSAn7k
# https://www.youtube.com/watch?v=fyRciI4iZPw
# https://www.youtube.com/watch?v=9jiqP9GziT8
# https://www.youtube.com/watch?v=1tjEGbV4xrU
# https://www.youtube.com/watch?v=1FpDJjzM7xg
# https://www.youtube.com/watch?v=ocW7Neuryow
# https://www.youtube.com/watch?v=sHgFwQiRuSM
# https://www.youtube.com/watch?v=A03ZzCajAus
# https://www.youtube.com/watch?v=mNTgk938t3o
# https://www.youtube.com/watch?v=HiIlguJ4I6I
# https://www.youtube.com/watch?v=IgzTO211Wec
# https://www.youtube.com/watch?v=yFU0yaFvuSI
# https://www.youtube.com/watch?v=g6-ijAuuUMw
# https://www.youtube.com/watch?v=p3iuKmAhIOw
# https://www.youtube.com/watch?v=28PtRJZ18HQ
# https://www.youtube.com/watch?v=DUPOYywVXNg
# https://www.youtube.com/watch?v=6RnNu2AM6uQ
# https://www.youtube.com/watch?v=E83F0JF_h58
# https://www.youtube.com/watch?v=-9P8U8usoLc
# https://www.youtube.com/watch?v=qDzTKoKf920
# https://www.youtube.com/watch?v=vT9V5q9gBOY
# https://www.youtube.com/watch?v=ivZFNCPTyFk
# https://www.youtube.com/watch?v=le8327ISSDU
# https://www.youtube.com/watch?v=opK8AM7uncE
# https://www.youtube.com/watch?v=4GZLuf9y1O4
# https://www.youtube.com/watch?v=u4iqODWQx34
# https://www.youtube.com/watch?v=mkuBQPBcnMI
# https://www.youtube.com/watch?v=1LaU5H1jaw4
# https://www.youtube.com/watch?v=h1mfVnQc7RU
# https://www.youtube.com/watch?v=NB0JF96FKjQ
# https://www.youtube.com/watch?v=lfU4T1XPirs
# https://www.youtube.com/watch?v=-Vh39s6oCvU
# https://www.youtube.com/watch?v=ZwN-2E0nunI
# https://www.youtube.com/watch?v=Y1uDn7Y2LJo
# https://www.youtube.com/watch?v=Blmuu1euDOI
# https://www.youtube.com/watch?v=4ZOmJN7StgM
# https://www.youtube.com/watch?v=ryrbrrjSgf4
# https://www.youtube.com/watch?v=4M8J4Q4F8Xk
# https://www.youtube.com/watch?v=epw58vCSDTw
# https://www.youtube.com/watch?v=neP5mgRygO8
# https://www.youtube.com/watch?v=nMRyIaA66HI
# https://www.youtube.com/watch?v=e5ZOUnutA80
# https://www.youtube.com/watch?v=AuWE7HJV9xI
# https://www.youtube.com/watch?v=kSmNQCNAACw
# https://www.youtube.com/watch?v=Dw7Qdgygmqs
# https://www.youtube.com/watch?v=WG9BH9iZX6I
# https://www.youtube.com/watch?v=93dwpLbjNnQ
#                                                url  \
# 0      https://www.youtube.com/watch?v=X1TvrRq5HgM
# 1      https://www.youtube.com/watch?v=X1TvrRq5HgM
# 2      https://www.youtube.com/watch?v=X1TvrRq5HgM
# 3      https://www.youtube.com/watch?v=X1TvrRq5HgM
# 4      https://www.youtube.com/watch?v=X1TvrRq5HgM
# ...                                            ...
# 94531  https://www.youtube.com/watch?v=93dwpLbjNnQ
# 94532  https://www.youtube.com/watch?v=93dwpLbjNnQ
# 94533  https://www.youtube.com/watch?v=93dwpLbjNnQ
# 94534  https://www.youtube.com/watch?v=93dwpLbjNnQ
# 94535  https://www.youtube.com/watch?v=93dwpLbjNnQ
#
#                                                    title  \
# 0      Uriah Hall vs. Anderson Silva full fight highl...
# 1      Uriah Hall vs. Anderson Silva full fight highl...
# 2      Uriah Hall vs. Anderson Silva full fight highl...
# 3      Uriah Hall vs. Anderson Silva full fight highl...
# 4      Uriah Hall vs. Anderson Silva full fight highl...
# ...                                                  ...
# 94531  UFC 254: Khabib vs Gaethje - This is My Dream ...
# 94532  UFC 254: Khabib vs Gaethje - This is My Dream ...
# 94533  UFC 254: Khabib vs Gaethje - This is My Dream ...
# 94534  UFC 254: Khabib vs Gaethje - This is My Dream ...
# 94535  UFC 254: Khabib vs Gaethje - This is My Dream ...
#
#                                        host  \
# 0                          MMAFightingonSBN
# 1                          MMAFightingonSBN
# 2                          MMAFightingonSBN
# 3                          MMAFightingonSBN
# 4                          MMAFightingonSBN
# ...                                     ...
# 94531  UFC - Ultimate Fighting Championship
# 94532  UFC - Ultimate Fighting Championship
# 94533  UFC - Ultimate Fighting Championship
# 94534  UFC - Ultimate Fighting Championship
# 94535  UFC - Ultimate Fighting Championship
#
#                                  host_url  \
# 0      https://www.youtube.com/user/spotv
# 1      https://www.youtube.com/user/spotv
# 2      https://www.youtube.com/user/spotv
# 3      https://www.youtube.com/user/spotv
# 4      https://www.youtube.com/user/spotv
# ...                                   ...
# 94531    https://www.youtube.com/user/UFC
# 94532    https://www.youtube.com/user/UFC
# 94533    https://www.youtube.com/user/UFC
# 94534    https://www.youtube.com/user/UFC
# 94535    https://www.youtube.com/user/UFC
#
#                                                   avatar             follow  \
# 0      https://yt3.ggpht.com/a/AATXAJwYT1H_cokAEcG9TE...  1.17M subscribers
# 1      https://yt3.ggpht.com/a/AATXAJwYT1H_cokAEcG9TE...  1.17M subscribers
# 2      https://yt3.ggpht.com/a/AATXAJwYT1H_cokAEcG9TE...  1.17M subscribers
# 3      https://yt3.ggpht.com/a/AATXAJwYT1H_cokAEcG9TE...  1.17M subscribers
# 4      https://yt3.ggpht.com/a/AATXAJwYT1H_cokAEcG9TE...  1.17M subscribers
# ...                                                  ...                ...
# 94531  https://yt3.ggpht.com/a/AATXAJywCaNCSgdV7Pn20m...  10.6M subscribers
# 94532  https://yt3.ggpht.com/a/AATXAJywCaNCSgdV7Pn20m...  10.6M subscribers
# 94533  https://yt3.ggpht.com/a/AATXAJywCaNCSgdV7Pn20m...  10.6M subscribers
# 94534  https://yt3.ggpht.com/a/AATXAJywCaNCSgdV7Pn20m...  10.6M subscribers
# 94535  https://yt3.ggpht.com/a/AATXAJywCaNCSgdV7Pn20m...  10.6M subscribers
#
#              upload           view  \
# 0       Nov 1, 2020    69085 views
# 1       Nov 1, 2020    69085 views
# 2       Nov 1, 2020    69085 views
# 3       Nov 1, 2020    69085 views
# 4       Nov 1, 2020    69085 views
# ...             ...            ...
# 94531  Oct 19, 2020  1481890 views
# 94532  Oct 19, 2020  1481890 views
# 94533  Oct 19, 2020  1481890 views
# 94534  Oct 19, 2020  1481890 views
# 94535  Oct 19, 2020  1481890 views
#
#                                                thumbnail likes hates  \
# 0      https://i.ytimg.com/vi/X1TvrRq5HgM/hqdefault.j...   632    45
# 1      https://i.ytimg.com/vi/X1TvrRq5HgM/hqdefault.j...   632    45
# 2      https://i.ytimg.com/vi/X1TvrRq5HgM/hqdefault.j...   632    45
# 3      https://i.ytimg.com/vi/X1TvrRq5HgM/hqdefault.j...   632    45
# 4      https://i.ytimg.com/vi/X1TvrRq5HgM/hqdefault.j...   632    45
# ...                                                  ...   ...   ...
# 94531  https://i.ytimg.com/vi/93dwpLbjNnQ/hq720.jpg?s...   27K   753
# 94532  https://i.ytimg.com/vi/93dwpLbjNnQ/hq720.jpg?s...   27K   753
# 94533  https://i.ytimg.com/vi/93dwpLbjNnQ/hq720.jpg?s...   27K   753
# 94534  https://i.ytimg.com/vi/93dwpLbjNnQ/hq720.jpg?s...   27K   753
# 94535  https://i.ytimg.com/vi/93dwpLbjNnQ/hq720.jpg?s...   27K   753
#
#                                                  comment
# 0       I'm sad to see these last few unsuccessful ye...
# 1       Uriah Hall still doing his best to destroy hi...
# 2       Man Anderson Silva and Dana White have some c...
# 3       whittaker didnt say he doesnt want the fight ...
# 4       Legend Silva Done a lot for the sport Seen hi...
# ...                                                  ...
# 94531         Get ready for that khabib its coming homie
# 94532                                        Khabib time
# 94533                                        Khabib time
# 94534                                        Khabib time
# 94535   Khabib is way too modest he s not the most do...
#
# [94536 rows x 12 columns]
